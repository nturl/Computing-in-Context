# %% [markdown]
# # COMS W1002 : Computing in Context
# ## Lecture 23: Beautiful Soup

# %% [markdown]
# Beautiful Soup is a very useful way to extract information from web pages. Documentation can be found here: https://www.crummy.com/software/BeautifulSoup/bs4/doc/

# %% [markdown]
# **Example 1**

# %%
#example of use

import bs4
import requests

#make a string to record where
loc='http://www.cs.columbia.edu/~cannon/exampleIndex.html'

#create the response object using requests.get
r=requests.get(loc)

# %%
r.text
# Out:
# '<html>\n<head>\n<title>Adam Cannon\'s Home Page</title>\n</head>\n\n<body bgcolor="gray">\n<h2 align= center>Adam Cannon</br>\n</br>\n<img align=left src = "pic.jpg" width="225" height="175"></h2>\n<font size=2>\n<b>Mailing Address:</b></br>\nDepartment of Computer Science </br>\nColumbia University</br>\n1214 Amsterdam Avenue, MC 0401</br>\nNew York, NY 10027</br>\n</br>\n<b>office:</b> 459 Computer Science Building</br>\n<b>tel:</b> (212) 939-7016</br>\n<b>fax:</b> (212) 666-0140</br>\n<font size=3>\n<b>e-mail: </b><a\nhref="mailto:cannon@cs.columbia.edu"><tt>cannon@cs.columbia.edu</tt></a></br></b>\n<font size=2>\n<hr>\n<ul>\n<p>\n\nI am a faculty member in the \n<a\nhref="http://www.cs.columbia.edu">Department of Computer Science</a> at <a\nhref="http://www.columbia.edu">Columbia University</a>. \n</br>\n\n</ul>\n<p>\n<h3> Education </h3>\n<ul>\n<li>Ph.D. Applied Mathematics, <a \nhref="http://www.jhu.edu">Johns Hopkins University</a>.</br>\n<li>M.A. Applied Mathematics, Johns Hopkins University.</br>\n<li>M.S. Aerospace Engineering, <a href="http://www.ucla.edu">University\nof California Los Angeles</a>.</br>\n<li>B.S. Aerospace Engineering, University of California Los Angeles. \n</b>\n</ul>\n<p>\n\n\n<h3>Current research interests are in: </h3>\n<ul>\nComputer Science Education</br>\nMachine Learning</br>\nStatistical Pattern Recognition</br>\nApproximation Algorithms</br>\nRandomized Agorithms</br>\n</ul>\n<p>\n\n<h3> Teaching Fall 2019: </h3>\n<ul>\nComputing in Context COMS W1002<br\n</br>\nIntroduction to Information Science COMS W1001 </br>\n</br><b>Office hours:</b> See OH calendar linked from actual webpage\n</ul>\n</br>\n</br>\n</br>\n<hr>\n\nTo my <a href="http://www.cs.columbia.edu/~cannon/">real homepage</a> </br>\n\n</br>\nBack to <a href="http://www.cs.columbia.edu">Computer Science Home Page.</a>\n</ul>\n\n<p>\n\n\n\n</ul>\n\n\n</body>\n\n</html>\n'

# %%
#create the soup object
soup=bs4.BeautifulSoup(r.content,'html.parser')

# now lets check out some methods
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    Adam Cannon's Home Page
#   </title>
#  </head>
#  <body bgcolor="gray">
#   <h2 align="center">
#    Adam Cannon
#    <img align="left" height="175" src="pic.jpg" width="225"/>
#   </h2>
#   <font size="2">
#    <b>
#     Mailing Address:
#    </b>
#    Department of Computer Science
#    Columbia University
#    1214 Amsterdam Avenue, MC 0401
#    New York, NY 10027
#    <b>
#     office:
#    </b>
#    459 Computer Science Building
#    <b>
#     tel:
#    </b>
#    (212) 939-7016
#    <b>
#     fax:
#    </b>
#    (212) 666-0140
#    <font size="3">
#     <b>
#      e-mail:
#     </b>
#     <a href="mailto:cannon@cs.columbia.edu">
#      <tt>
#       cannon@cs.columbia.edu
#      </tt>
#     </a>
#     <font size="2">
#      <hr/>
#      <ul>
#       <p>
#        I am a faculty member in the
#        <a href="http://www.cs.columbia.edu">
#         Department of Computer Science
#        </a>
#        at
#        <a href="http://www.columbia.edu">
#         Columbia University
#        </a>
#        .
#       </p>
#      </ul>
#      <p>
#       <h3>
#        Education
#       </h3>
#       <ul>
#        <li>
#         Ph.D. Applied Mathematics,
#         <a href="http://www.jhu.edu">
#          Johns Hopkins University
#         </a>
#         .
#         <li>
#          M.A. Applied Mathematics, Johns Hopkins University.
#          <li>
#           M.S. Aerospace Engineering,
#           <a href="http://www.ucla.edu">
#            University
# of California Los Angeles
#           </a>
#           .
#           <li>
#            B.S. Aerospace Engineering, University of California Los Angeles.
#           </li>
#          </li>
#         </li>
#        </li>
#       </ul>
#       <p>
#        <h3>
#         Current research interests are in:
#        </h3>
#        <ul>
#         Computer Science Education
#         Machine Learning
#         Statistical Pattern Recognition
#         Approximation Algorithms
#         Randomized Agorithms
#        </ul>
#        <p>
#         <h3>
#          Teaching Fall 2019:
#         </h3>
#         <ul>
#          Computing in Context COMS W1002
#          <br <="" br=""/>
#          Introduction to Information Science COMS W1001
#          <b>
#           Office hours:
#          </b>
#          See OH calendar linked from actual webpage
#         </ul>
#         <hr/>
#         To my
#         <a href="http://www.cs.columbia.edu/~cannon/">
#          real homepage
#         </a>
#         Back to
#         <a href="http://www.cs.columbia.edu">
#          Computer Science Home Page.
#         </a>
#         <p>
#         </p>
#        </p>
#       </p>
#      </p>
#     </font>
#    </font>
#   </font>
#  </body>
# </html>

# %%
#find and find_all
print(soup.find('title').get_text())
# Out:
# Adam Cannon's Home Page

# %%
for l in soup.find_all('a'):
    print(l.get('href'))
# Out:
# mailto:cannon@cs.columbia.edu
# http://www.cs.columbia.edu
# http://www.columbia.edu
# http://www.jhu.edu
# http://www.ucla.edu
# http://www.cs.columbia.edu/~cannon/
# http://www.cs.columbia.edu

# %% [markdown]
# **Example 2**
# Let's scrape the current status of the lifts at a local(ish) ski resort..

# %%
# same as before but a different url
loc2='https://whiteface.com/mountain/conditions/'
r2=requests.get(loc2)
soup2=bs4.BeautifulSoup(r2.content,'html.parser')

print(soup2.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]><html lang="en-US" class="no-js lt-ie9 lt-ie8 lt-ie7"><![endif]-->
# <!--[if (IE 7)&!(IEMobile)]><html lang="en-US" class="no-js lt-ie9 lt-ie8"><![endif]-->
# <!--[if (IE 8)&!(IEMobile)]><html lang="en-US" class="no-js lt-ie9"><![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js" itemscope="itemscope" itemtype="https://schema.org/WebPage" lang="en-US">
#  <!--<![endif]-->
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="ie=edge" http-equiv="x-ua-compatible"/>
#   <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
#   <link href="https://whiteface.com/wp-content/themes/plate-orda/favicon.png" rel="icon"/>
#   <meta content="kwj19izoa4awymr9y245l2fw8ubbgw" name="facebook-domain-verification">
#    <meta content="index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1" name="robots">
#     <!-- This site is optimized with the Yoast SEO plugin v17.5 - https://yoast.com/wordpress/plugins/seo/ -->
#     <title>
#      Snow Report - Updates On Weather and Lift &amp; Trail Conditions | Whiteface
#     </title>
#     <meta content="Tune in here for daily updates on weather, lift and trail conditions, dining, après, and insider tips on getting the most out of your day at Whiteface." name="description">
#      <link href="https://whiteface.com/mountain/conditions/" rel="canonical">
#       <meta content="en_US" property="og:locale"/>
#       <meta content="article" property="og:type"/>
#       <meta content="Snow Report - Updates On Weather and Lift &amp; Trail Conditions | Whiteface" property="og:title"/>
#       <meta content="Tune in here for daily updates on weather, lift and trail conditions, dining, après, and insider tips on getting the most out of your day at Whiteface." property="og:description"/>
#       <meta content="https://whiteface.com/mountain/conditions/" property="og:url"/>
#       <meta content="Whiteface Mountain" property="og:site_name"/>
#       <meta content="2021-11-16T22:18:44+00:00" property="article:modified_time"/>
#       <meta content="https://whiteface.com/wp-content/uploads/sites/3/2020/12/Little-Whiteface-snow-corduroy-ski_1920x950.jpg" property="og:image"/>
#       <meta content="1920" property="og:image:width"/>
#       <meta content="950" property="og:image:height"/>
#       <meta content="summary_large_image" name="twitter:card"/>
#       <script class="yoast-schema-graph" type="application/ld+json">
#        {"@context":"https://schema.org","@graph":[{"@type":"WebSite","@id":"https://whiteface.com/#website","url":"https://whiteface.com/","name":"Whiteface Mountain","description":"Just another Lake Placid Olympic Sites Network site","potentialAction":[{"@type":"SearchAction","target":{"@type":"EntryPoint","urlTemplate":"https://whiteface.com/?s={search_term_string}"},"query-input":"required name=search_term_string"}],"inLanguage":"en-US"},{"@type":"ImageObject","@id":"https://whiteface.com/mountain/conditions/#primaryimage","inLanguage":"en-US","url":"https://whiteface.com/wp-content/uploads/sites/3/2020/12/Little-Whiteface-snow-corduroy-ski_1920x950.jpg","contentUrl":"https://whiteface.com/wp-content/uploads/sites/3/2020/12/Little-Whiteface-snow-corduroy-ski_1920x950.jpg","width":1920,"height":950,"caption":"Skis on fresh corduroy with Whiteface in the background."},{"@type":"WebPage","@id":"https://whiteface.com/mountain/conditions/#webpage","url":"https://whiteface.com/mountain/conditions/","name":"Snow Report - Updates On Weather and Lift & Trail Conditions | Whiteface","isPartOf":{"@id":"https://whiteface.com/#website"},"primaryImageOfPage":{"@id":"https://whiteface.com/mountain/conditions/#primaryimage"},"datePublished":"2020-06-09T12:22:58+00:00","dateModified":"2021-11-16T22:18:44+00:00","description":"Tune in here for daily updates on weather, lift and trail conditions, dining, apr\u00e8s, and insider tips on getting the most out of your day at Whiteface.","breadcrumb":{"@id":"https://whiteface.com/mountain/conditions/#breadcrumb"},"inLanguage":"en-US","potentialAction":[{"@type":"ReadAction","target":["https://whiteface.com/mountain/conditions/"]}]},{"@type":"BreadcrumbList","@id":"https://whiteface.com/mountain/conditions/#breadcrumb","itemListElement":[{"@type":"ListItem","position":1,"name":"Home","item":"https://whiteface.com/"},{"@type":"ListItem","position":2,"name":"Mountain","item":"https://whiteface.com/mountain/"},{"@type":"ListItem","position":3,"name":"Conditions"}]}]}
#       </script>
#       <!-- / Yoast SEO plugin. -->
#       <link href="//www.google.com" rel="dns-prefetch"/>
#       <link href="//code.jquery.com" rel="dns-prefetch"/>
#       <link href="//cdn.jsdelivr.net" rel="dns-prefetch"/>
#       <link href="//cdnjs.cloudflare.com" rel="dns-prefetch"/>
#       <link href="//s.w.org" rel="dns-prefetch"/>
#       <link href="https://whiteface.com/wp-content/plugins/instagram-feed/css/sbi-styles.min.css?ver=2.9.5" id="sb_instagram_styles-css" media="all" rel="stylesheet" type="text/css"/>
#       <link href="https://whiteface.com/wp-content/themes/plate-orda/library/css/gutenberg.css?ver=1638275244" id="plate-gutenberg-styles-css" media="all" rel="stylesheet" type="text/css"/>
#       <link href="https://whiteface.com/wp-content/plugins/cookie-law-info/public/css/cookie-law-info-public.css?ver=2.0.6" id="cookie-law-info-css" media="all" rel="stylesheet" type="text/css"/>
#       <link href="https://whiteface.com/wp-content/plugins/cookie-law-info/public/css/cookie-law-info-gdpr.css?ver=2.0.6" id="cookie-law-info-gdpr-css" media="all" rel="stylesheet" type="text/css"/>
#       <link href="https://whiteface.com/wp-content/plugins/orda-conditions/css/orda-style.css?ver=20210923-150637" id="orda-conditions-stylesheet-css" media="all" rel="stylesheet" type="text/css"/>
#       <link href="https://whiteface.com/wp-content/plugins/orda-lodging/css/orda-lodging-style.css?ver=20200727-142133" id="orda-lodging-stylesheet-css" media="all" rel="stylesheet" type="text/css"/>
#       <link href="https://whiteface.com/wp-content/plugins/orda-lodging/css/orda-lodging-print-style.css?ver=20200727-142133" id="orda-lodging-print-stylesheet-css" media="print" rel="stylesheet" type="text/css"/>
#       <link href="https://whiteface.com/wp-content/themes/plate-orda/library/css/style.css?ver=1638275244" id="plate-stylesheet-css" media="all" rel="stylesheet" type="text/css"/>
#       <link href="https://whiteface.com/wp-content/themes/child-whiteface/library/css/style.css?ver=1638275244" id="child-style-css" media="all" rel="stylesheet" type="text/css"/>
#       <link href="https://whiteface.com/wp-content/plugins/tablepress/css/default.min.css?ver=1.14" id="tablepress-default-css" media="all" rel="stylesheet" type="text/css"/>
#       <link href="https://whiteface.com/wp-content/plugins/tablepress-responsive-tables/css/tablepress-responsive.min.css?ver=1.8" id="tablepress-responsive-tables-css" media="all" rel="stylesheet" type="text/css"/>
#       <!--[if lt IE 9]>
# <link rel='stylesheet' id='plate-ie-only-css'  href='https://whiteface.com/wp-content/themes/plate-orda/library/css/ie.css?ver=1638275244' type='text/css' media='all' />
# <![endif]-->
#       <script id="jquery-js" src="//code.jquery.com/jquery-3.4.1.min.js?ver=5.8.2" type="text/javascript">
#       </script>
#       <script id="cookie-law-info-js-extra" type="text/javascript">
#        /* <![CDATA[ */
# var Cli_Data = {"nn_cookie_ids":[],"cookielist":[],"non_necessary_cookies":[],"ccpaEnabled":"","ccpaRegionBased":"","ccpaBarEnabled":"","strictlyEnabled":["necessary","obligatoire"],"ccpaType":"gdpr","js_blocking":"","custom_integration":"","triggerDomRefresh":"","secure_cookies":""};
# var cli_cookiebar_settings = {"animate_speed_hide":"500","animate_speed_show":"500","background":"#FFF","border":"#b1a6a6c2","border_on":"","button_1_button_colour":"#000","button_1_button_hover":"#000000","button_1_link_colour":"#fff","button_1_as_button":"1","button_1_new_win":"","button_2_button_colour":"#333","button_2_button_hover":"#292929","button_2_link_colour":"#444","button_2_as_button":"1","button_2_hidebar":"1","button_3_button_colour":"#000","button_3_button_hover":"#000000","button_3_link_colour":"#fff","button_3_as_button":"1","button_3_new_win":"","button_4_button_colour":"#000","button_4_button_hover":"#000000","button_4_link_colour":"#62a329","button_4_as_button":"","button_7_button_colour":"#61a229","button_7_button_hover":"#4e8221","button_7_link_colour":"#fff","button_7_as_button":"1","button_7_new_win":"","font_family":"inherit","header_fix":"","notify_animate_hide":"1","notify_animate_show":"","notify_div_id":"#cookie-law-info-bar","notify_position_horizontal":"right","notify_position_vertical":"bottom","scroll_close":"","scroll_close_reload":"","accept_close_reload":"","reject_close_reload":"","showagain_tab":"1","showagain_background":"#fff","showagain_border":"#000","showagain_div_id":"#cookie-law-info-again","showagain_x_position":"100px","text":"#000","show_once_yn":"","show_once":"10000","logging_on":"","as_popup":"","popup_overlay":"1","bar_heading_text":"","cookie_bar_as":"banner","popup_showagain_position":"bottom-right","widget_position":"left"};
# var log_object = {"ajax_url":"https:\/\/whiteface.com\/wp-admin\/admin-ajax.php"};
# /* ]]> */
#       </script>
#       <script id="cookie-law-info-js" src="https://whiteface.com/wp-content/plugins/cookie-law-info/public/js/cookie-law-info-public.js?ver=2.0.6" type="text/javascript">
#       </script>
#       <link href="https://whiteface.com/wp-json/" rel="https://api.w.org/"/>
#       <link href="https://whiteface.com/wp-json/wp/v2/pages/217" rel="alternate" type="application/json"/>
#       <link href="https://whiteface.com/?p=217" rel="shortlink"/>
#       <link href="https://whiteface.com/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fwhiteface.com%2Fmountain%2Fconditions%2F" rel="alternate" type="application/json+oembed"/>
#       <link href="https://whiteface.com/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fwhiteface.com%2Fmountain%2Fconditions%2F&amp;format=xml" rel="alternate" type="text/xml+oembed"/>
#       <script src="https://wpa.lakeplacidolympicsites.com/?dm=5e37d2defc28328f0e6e5488a0b6f70d&amp;action=load&amp;blogid=3&amp;siteid=1&amp;t=696310223&amp;back=https%3A%2F%2Fwhiteface.com%2Fmountain%2Fconditions%2F" type="text/javascript">
#       </script>
#       <script type="text/javascript">
#        var cli_flush_cache = true;
#       </script>
#       <style type="text/css">
#        header.header .site-title a {
#           color: #000;
#         }
#
#
#         #banner .header-image {
#           max-width: 100%;
#           height: auto;
#         }
#
#         .customize-control-description {
#           font-style: normal;
#         }
#       </style>
#       <!-- Google Tag Manager -->
#       <script>
#        (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start': new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0], j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f); })(window,document,'script','dataLayer','GTM-KHF9JLP');
#       </script>
#       <!-- End Google Tag Manager -->
#      </link>
#     </meta>
#    </meta>
#   </meta>
#  </head>
#  <body class="page-template page-template-page-flex-a page-template-page-flex-a-php page page-id-217 page-parent page-child parent-pageid-216 wp-embed-responsive site-id-3 page-conditions-winter page-flex-a-php conditions mountain template-page-flex-a-php page-mountain page-conditions" data-hostname="whiteface.com" data-permalink="https://whiteface.com/mountain/conditions/" data-request-uri="/mountain/conditions/" itemscope="" itemtype="https://schema.org/WebPage">
#   <!-- Google Tag Manager (noscript) -->
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-KHF9JLP" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <!-- End Google Tag Manager (noscript) -->
#   <div name="top">
#   </div>
#   <div class="grid grid-aside" id="container">
#    <header class="header" data-weather-icon="cloudy" id="header" itemscope="" itemtype="https://schema.org/WPHeader" role="banner">
#     <div class="wrap desk-nav-search-closed" id="inner-header">
#      <div class="mobile-header-sticky mq-mobilemenuonly">
#       <div class="mobile-menu-button">
#        <i class="mdi mdi-menu">
#        </i>
#       </div>
#      </div>
#      <div class="mobile-header">
#       <div class="sticky-bar msg-count-1" data-msg-count="1" data-sticky-name="LPOS-aa714b0944f210fc60eb25c12136ec5c">
#        <div class="sticky-bar-inner">
#         <div class="message">
#          <a href="https://whiteface.com/health-safety-information/" target="" title="Review Guidelines »">
#           Review our COVID Prevention Guidelines for Whiteface here »
#          </a>
#         </div>
#        </div>
#        <div class="dismiss-button">
#         <icon class="mdi mdi-window-close">
#         </icon>
#        </div>
#       </div>
#       <div class="inner-wrap">
#        <div class="logo">
#         <a href="https://whiteface.com/">
#          <img alt="Whiteface Mountain" src="https://whiteface.com/wp-content/themes/child-whiteface/library/images/logos/logo-whiteface.svg"/>
#         </a>
#        </div>
#        <div class="mobile-menu-button">
#         <i class="mdi mdi-menu">
#         </i>
#        </div>
#       </div>
#      </div>
#      <div class="desktop-header-sticky mq-desktopmenuonly hidden">
#       <div class="inner-wrap">
#        <div class="logo">
#         <a href="https://whiteface.com/">
#          <svg height="65" id="logo-whiteface" viewbox="0 0 355 65" width="355" xmlns="http://www.w3.org/2000/svg">
#           <title>
#            Whiteface Mountain
#           </title>
#           <g data-name="WH LOGO HO" id="WH_LOGO_HO" transform="translate(-56.196 -40.748)">
#            <path d="M39.456,47.975,0,63,38.66,24.606l-2.831,9.766L19.984,50.2l19.474-7.7,19.47,7.718L43.087,34.376,40.243,24.6,78.914,63.011Zm-1.691-28.4c-1.371-1.867-5.338-7.328-.35-10.148,3.945-2.231,4.358-5.23,3.735-6.849,0,0,2.15,3.3.655,6.537-.913,1.978-1.826,2.776-1.5,3.517a.833.833,0,0,0,1.5.071,1.71,1.71,0,0,0-.09-1.366s3.239,2.348,2.367,5.462-4.142,4.3-4.636,6.03A9.986,9.986,0,0,0,37.765,19.571Zm.424-15.5A3.755,3.755,0,0,0,39.282,0a5.466,5.466,0,0,1-1.671,8.041S36.722,5.424,38.19,4.067Z" data-name="Union 8" fill="#f8f8f8" id="Union_8" stroke="rgba(0,0,0,0)" stroke-miterlimit="10" stroke-width="1" transform="translate(58.221 42.423)">
#            </path>
#            <path d="M207.893,14.089V8.126s.022-3.805-1.308-4.757l20.261,0a1.656,1.656,0,0,0-1.444,1.79c0,1.663-.071,3.289-.071,3.289l-3.76.542V6.163l-1.96-.066-7.936.03a14.46,14.46,0,0,0-.157,2.007V14.1A15.037,15.037,0,0,0,211.6,15.8l8.175.03,1.79-.112V12.465l3.76.759-.023,2.319c0,3.044,1.631,3.146,1.631,3.146l-20.343.024S207.893,18.233,207.893,14.089Zm30.966,0V8.123s.021-3.8-1.308-4.753l17.751,0V7.4c-.951-1.33-4.73-1.308-4.73-1.308l-7.934.03a14.543,14.543,0,0,0-.157,2.007V9.372h2.864c4.142,0,4.625-1.3,4.625-1.3l0,3.728h-.01l0,1.524s-.482-1.3-4.624-1.3h-2.856v2.073a14.971,14.971,0,0,0,.088,1.7l8.175.032s3.777.021,4.729-1.308l-.007,4.168-17.909.021S238.858,18.228,238.858,14.086Zm-85.546,0V8.119s.019-3.777-1.308-4.73h17.467l0,4.008c-.951-1.328-4.73-1.308-4.73-1.308l-7.653.031a14.648,14.648,0,0,0-.155,2.007v2h2.188c4.142,0,4.622-1.3,4.622-1.3l-.007,5.251s-.482-1.3-4.623-1.3h-2.179v1.3l0,0c0,4.141,1.3,4.623,1.3,4.623l-6.227,0S153.312,18.225,153.312,14.081ZM99.767,18.7s1.3-.48,1.3-4.624V8.109a14.427,14.427,0,0,0-.154-1.978H98.34s-3.778-.021-4.73,1.307l.007-4.049h18.5l.019,4.017c-.952-1.33-4.726-1.308-4.726-1.308h-2.568a14.228,14.228,0,0,0-.156,2.021V14.08c0,4.143,1.3,4.625,1.3,4.625Zm-23.109,0s1.3-.481,1.3-4.623V8.106s.019-3.777-1.309-4.729l6.237.009c-1.328.951-1.307,4.728-1.307,4.728v5.964c0,4.141,1.3,4.624,1.3,4.624Zm47.556-4.619V8.11s.021-3.776-1.307-4.727l17.75,0V7.389c-.951-1.328-4.731-1.307-4.731-1.307l-7.935.03a14.44,14.44,0,0,0-.155,2.006V9.361H130.7c4.144,0,4.623-1.3,4.623-1.3l0,3.729h-.01l0,1.521s-.483-1.3-4.624-1.3h-2.856v2.072a15.251,15.251,0,0,0,.087,1.707l8.174.03s3.78.02,4.731-1.308l-.014,4.179-17.9.009S124.213,18.219,124.213,14.075ZM58.153,18.69s1.3-.481,1.3-4.621V12.1H48.34v1.977c0,4.142,1.3,4.622,1.3,4.622l-6.223-.008s1.3-.481,1.3-4.621V8.1s.02-3.778-1.308-4.728l6.238.007c-1.328.951-1.307,4.729-1.307,4.729V9.274H59.455V8.105s.02-3.778-1.309-4.729l6.239.007c-1.328.951-1.308,4.73-1.308,4.73v5.963c0,4.142,1.3,4.622,1.3,4.622Zm-50.547-.06s1.353-.743.622-2.7-5.051-13.2-5.051-13.2A3.893,3.893,0,0,0,0,0L8.235,0a2.245,2.245,0,0,0-.609,2.7l3.712,9.814s3.042-7.812,3.878-9.805S14.711,0,14.711,0l6.342.012c-1.334.7-.622,2.719-.622,2.719l3.939,9.79,3.532-9.8S28.716.589,27.4,0l7.49.019A4.422,4.422,0,0,0,31.66,2.684L26.644,15.929s-.908,1.819.566,2.7l-6.3,0a2.177,2.177,0,0,0,.62-2.7L17.511,5.771,13.338,15.927s-.838,1.844.491,2.712Zm183.132-.011a2.378,2.378,0,0,0,.5-3.305H181.1c-1.273,2.2.437,3.323.437,3.323h-7.894a4.827,4.827,0,0,0,3.255-2.41s5.1-8.672,6.021-10.224a2.089,2.089,0,0,0-.625-2.7l8.04.009c-1.6,1.4-.617,2.715-.617,2.715l6.137,10.144a5.027,5.027,0,0,0,3.208,2.468Zm-8.046-6.1h7.025l-3.585-6.367Z" data-name="Union 7" fill="#f8f8f8" id="Union_7" stroke="rgba(0,0,0,0)" stroke-miterlimit="10" stroke-width="1" transform="translate(154.747 66.341)">
#            </path>
#           </g>
#          </svg>
#         </a>
#        </div>
#        <div class="nav-buttons-wrapper">
#         <div class="desk-sticky-nav-container">
#         </div>
#         <div class="weather conditions" title="Light Snow">
#          <span class="weather-icon">
#           <svg height="48.185" viewbox="0 0 42.732 48.185" width="42.732" xmlns="http://www.w3.org/2000/svg">
#            <g id="icon-snowflake" transform="translate(-385.173 -2976.5)">
#             <line data-name="Line 54" fill="none" id="Line_54" stroke="#fff" stroke-linecap="round" stroke-linejoin="round" stroke-width="2" transform="translate(406.541 2977.5)" y2="46.185">
#             </line>
#             <line data-name="Line 55" fill="none" id="Line_55" stroke="#fff" stroke-linecap="round" stroke-linejoin="round" stroke-width="2" transform="translate(386.541 2989.046)" x2="39.998" y2="23.092">
#             </line>
#             <line data-name="Line 56" fill="none" id="Line_56" stroke="#fff" stroke-linecap="round" stroke-linejoin="round" stroke-width="2" transform="translate(386.539 2989.046)" x2="40" y1="23.094">
#             </line>
#             <g data-name="Group 648" id="Group_648" transform="translate(401.521 2981.516)">
#              <path d="M394,2979.5l5.02,5.02,5.02-5.02" data-name="Path 3454" fill="none" id="Path_3454" stroke="#fff" stroke-linecap="round" stroke-linejoin="round" stroke-width="2" transform="translate(-394 -2979.5)">
#              </path>
#             </g>
#             <g data-name="Group 649" id="Group_649" transform="translate(387.508 2986.707)">
#              <path d="M387.021,2990.779l6.859-1.837-1.839-6.858" data-name="Path 3455" fill="none" id="Path_3455" stroke="#fff" stroke-linecap="round" stroke-linejoin="round" stroke-width="2" transform="translate(-387.021 -2982.084)">
#              </path>
#             </g>
#             <g data-name="Group 650" id="Group_650" transform="translate(387.508 3005.785)">
#              <path d="M392.042,3000.281l1.839-6.859-6.859-1.836" data-name="Path 3456" fill="none" id="Path_3456" stroke="#fff" stroke-linecap="round" stroke-linejoin="round" stroke-width="2" transform="translate(-387.021 -2991.586)">
#              </path>
#             </g>
#             <g data-name="Group 651" id="Group_651" transform="translate(401.521 3014.649)">
#              <path d="M404.04,3001.022,399.018,2996,394,3001.022" data-name="Path 3457" fill="none" id="Path_3457" stroke="#fff" stroke-linecap="round" stroke-linejoin="round" stroke-width="2" transform="translate(-394 -2996)">
#              </path>
#             </g>
#             <g data-name="Group 652" id="Group_652" transform="translate(418.711 3005.785)">
#              <path d="M409.424,2991.586l-6.863,1.838,1.843,6.857" data-name="Path 3458" fill="none" id="Path_3458" stroke="#fff" stroke-linecap="round" stroke-linejoin="round" stroke-width="2" transform="translate(-402.56 -2991.586)">
#              </path>
#             </g>
#             <g data-name="Group 653" id="Group_653" transform="translate(418.713 2986.707)">
#              <path d="M404.4,2982.084l-1.841,6.862,6.861,1.833" data-name="Path 3459" fill="none" id="Path_3459" stroke="#fff" stroke-linecap="round" stroke-linejoin="round" stroke-width="2" transform="translate(-402.561 -2982.084)">
#              </path>
#             </g>
#             <line data-name="Line 57" fill="none" id="Line_57" stroke="#fff" stroke-linecap="round" stroke-linejoin="round" stroke-width="2" transform="translate(403.529 2991.556)" x2="6.024">
#             </line>
#             <line data-name="Line 58" fill="none" id="Line_58" stroke="#fff" stroke-linecap="round" stroke-linejoin="round" stroke-width="2" transform="translate(397.207 2993.464)" x2="3.012" y1="5.218">
#             </line>
#             <line data-name="Line 59" fill="none" id="Line_59" stroke="#fff" stroke-linecap="round" stroke-linejoin="round" stroke-width="2" transform="translate(397.207 3002.504)" x1="3.012" y1="5.216">
#             </line>
#             <line data-name="Line 60" fill="none" id="Line_60" stroke="#fff" stroke-linecap="round" stroke-linejoin="round" stroke-width="2" transform="translate(403.529 3009.631)" x1="6.024">
#             </line>
#             <line data-name="Line 61" fill="none" id="Line_61" stroke="#fff" stroke-linecap="round" stroke-linejoin="round" stroke-width="2" transform="translate(412.861 3002.502)" x1="3.012" y2="5.218">
#             </line>
#             <line data-name="Line 62" fill="none" id="Line_62" stroke="#fff" stroke-linecap="round" stroke-linejoin="round" stroke-width="2" transform="translate(412.859 2993.464)" x2="3.014" y2="5.22">
#             </line>
#            </g>
#           </svg>
#          </span>
#          <span class="location">
#           <span>
#            Daily
#           </span>
#           Conditions
#          </span>
#          <div class="cr conditions-widget conditions-report snow-report">
#           <div class="row top-section">
#            <div class="inner">
#             <div class="report-box date">
#              <div class="title">
#               Tuesday
#              </div>
#              <div class="main-detail">
#               <span class="primary">
#                Nov 30
#               </span>
#               <span class="secondary">
#                2021
#               </span>
#              </div>
#              <div class="sub-detail">
#              </div>
#             </div>
#             <div class="report-box weather-data">
#              <div class="title">
#               Weather
#              </div>
#              <div class="main-detail">
#               <span class="primary">
#                19°F
#               </span>
#               <span class="secondary">
#                Light Snow
#               </span>
#              </div>
#              <div class="sub-detail">
#               <i class="wi wi-day-snow">
#               </i>
#              </div>
#             </div>
#             <div class="report-box snow">
#              <div class="title">
#               Snow
#              </div>
#              <div class="main-detail">
#               <span class="primary">
#                Packed Powder
#               </span>
#               <span class="secondary append-type">
#                Primary Surface
#               </span>
#              </div>
#              <div class="sub-detail">
#               <span class="primary">
#                Loose Granular
#               </span>
#               <span class="secondary append-type">
#                Secondary Surface
#               </span>
#              </div>
#              <div class="sub-detail">
#               <span class="primary">
#                24
#                <span class="append-inches">
#                 in
#                </span>
#               </span>
#               <span class="secondary append-type">
#                Season Total Depth
#               </span>
#              </div>
#             </div>
#             <div class="report-box lifts">
#              <div class="title">
#               Lifts
#              </div>
#              <div class="main-detail">
#               <span class="primary">
#                2
#               </span>
#               <span class="secondary">
#                of 11
#               </span>
#              </div>
#              <div class="sub-detail">
#              </div>
#             </div>
#             <div class="report-box trails">
#              <div class="title">
#               Trails
#              </div>
#              <div class="main-detail">
#               <span class="primary">
#                7
#               </span>
#               <span class="secondary">
#                of 90
#               </span>
#              </div>
#              <div class="sub-detail">
#              </div>
#             </div>
#             <div class="report-box alert">
#              <a class="view-report button" href="https://whiteface.com/mountain/conditions/">
#               View Report
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="buttons">
#          <div class="search-toggle" data-if-open-focus=".desktop-header-sticky .search-field" data-toggle-classes="sticky-nav-search-open sticky-nav-search-closed" data-toggle-target=".desktop-header-sticky" name="search-button">
#           <icon class="mdi mdi-magnify">
#           </icon>
#          </div>
#          <a class="store-link" data-accesso-keyword="whiteface" data-link-type="keyword" href="https://whiteface.com/">
#           <icon class="mdi mdi-cart-outline">
#           </icon>
#           <span>
#            Shop
#           </span>
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="desktop-search-container">
#        <form action="https://whiteface.com/" class="search-form" method="get" role="search">
#         <div class="search-input">
#          <label for="search-field-211130-10-11-38-955495-America-New-York">
#           <span class="search-label">
#            Search for:
#           </span>
#          </label>
#          <input class="search-field" id="search-field-211130-10-11-38-955495-America-New-York" name="s" placeholder="Search" title="Search for:" type="search" value=""/>
#          <button class="search-submit" type="submit" value="">
#           <span>
#            Search
#           </span>
#           <icon class="mdi mdi-magnify">
#           </icon>
#          </button>
#         </div>
#        </form>
#       </div>
#       <div class="sticky-bar msg-count-1" data-msg-count="1" data-sticky-name="LPOS-aa714b0944f210fc60eb25c12136ec5c">
#        <div class="sticky-bar-inner">
#         <div class="message">
#          <a href="https://whiteface.com/health-safety-information/" target="" title="Review Guidelines »">
#           Review our COVID Prevention Guidelines for Whiteface here »
#          </a>
#         </div>
#        </div>
#        <div class="dismiss-button">
#         <icon class="mdi mdi-window-close">
#         </icon>
#        </div>
#       </div>
#      </div>
#      <!-- // end .desktop-header-sticky -->
#      <div class="desktop-header">
#       <div class="inner-wrap">
#        <div class="col-one col-left">
#         <div class="top-bar locations-bar">
#          <div class="other-sites">
#           <a class="active-site" href="https://whiteface.com">
#            Whiteface
#           </a>
#           <span>
#            |
#           </span>
#           <a href="https://lakeplacidlegacysites.com" rel="noopener" target="_blank">
#            Legacy Sites
#           </a>
#           <span>
#            |
#           </span>
#           <a href="https://mtvanhoevenberg.com" rel="noopener" target="_blank">
#            Mt. Van Hoevenberg
#           </a>
#           <span>
#            |
#           </span>
#           <a href="https://goremountain.com" rel="noopener" target="_blank">
#            Gore
#           </a>
#           <span>
#            |
#           </span>
#           <a href="https://www.belleayre.com" rel="noopener" target="_blank">
#            Belleayre
#           </a>
#          </div>
#          <div class="other-links">
#           <a class="link-calendar" href="https://whiteface.com/calendar/" name="link-calendar" title="View Our Event Calendar">
#            <icon class="mdi mdi-calendar-month">
#            </icon>
#            <span>
#             Calendar
#            </span>
#           </a>
#           <a class="link-contact-us" href="https://whiteface.com/contact-us/" name="link-contact-us" title="Contact Us Today!">
#            <icon class="mdi mdi-email-outline">
#            </icon>
#            <span>
#             Contact
#             <span>
#              Us
#             </span>
#            </span>
#           </a>
#          </div>
#         </div>
#         <div class="main-bar logo-bar menu-bar">
#          <div class="logo">
#           <a href="https://whiteface.com/">
#            <svg height="65" id="logo-whiteface" viewbox="0 0 355 65" width="355" xmlns="http://www.w3.org/2000/svg">
#             <title>
#              Whiteface Mountain
#             </title>
#             <g data-name="WH LOGO HO" id="WH_LOGO_HO" transform="translate(-56.196 -40.748)">
#              <path d="M39.456,47.975,0,63,38.66,24.606l-2.831,9.766L19.984,50.2l19.474-7.7,19.47,7.718L43.087,34.376,40.243,24.6,78.914,63.011Zm-1.691-28.4c-1.371-1.867-5.338-7.328-.35-10.148,3.945-2.231,4.358-5.23,3.735-6.849,0,0,2.15,3.3.655,6.537-.913,1.978-1.826,2.776-1.5,3.517a.833.833,0,0,0,1.5.071,1.71,1.71,0,0,0-.09-1.366s3.239,2.348,2.367,5.462-4.142,4.3-4.636,6.03A9.986,9.986,0,0,0,37.765,19.571Zm.424-15.5A3.755,3.755,0,0,0,39.282,0a5.466,5.466,0,0,1-1.671,8.041S36.722,5.424,38.19,4.067Z" data-name="Union 8" fill="#f8f8f8" id="Union_8" stroke="rgba(0,0,0,0)" stroke-miterlimit="10" stroke-width="1" transform="translate(58.221 42.423)">
#              </path>
#              <path d="M207.893,14.089V8.126s.022-3.805-1.308-4.757l20.261,0a1.656,1.656,0,0,0-1.444,1.79c0,1.663-.071,3.289-.071,3.289l-3.76.542V6.163l-1.96-.066-7.936.03a14.46,14.46,0,0,0-.157,2.007V14.1A15.037,15.037,0,0,0,211.6,15.8l8.175.03,1.79-.112V12.465l3.76.759-.023,2.319c0,3.044,1.631,3.146,1.631,3.146l-20.343.024S207.893,18.233,207.893,14.089Zm30.966,0V8.123s.021-3.8-1.308-4.753l17.751,0V7.4c-.951-1.33-4.73-1.308-4.73-1.308l-7.934.03a14.543,14.543,0,0,0-.157,2.007V9.372h2.864c4.142,0,4.625-1.3,4.625-1.3l0,3.728h-.01l0,1.524s-.482-1.3-4.624-1.3h-2.856v2.073a14.971,14.971,0,0,0,.088,1.7l8.175.032s3.777.021,4.729-1.308l-.007,4.168-17.909.021S238.858,18.228,238.858,14.086Zm-85.546,0V8.119s.019-3.777-1.308-4.73h17.467l0,4.008c-.951-1.328-4.73-1.308-4.73-1.308l-7.653.031a14.648,14.648,0,0,0-.155,2.007v2h2.188c4.142,0,4.622-1.3,4.622-1.3l-.007,5.251s-.482-1.3-4.623-1.3h-2.179v1.3l0,0c0,4.141,1.3,4.623,1.3,4.623l-6.227,0S153.312,18.225,153.312,14.081ZM99.767,18.7s1.3-.48,1.3-4.624V8.109a14.427,14.427,0,0,0-.154-1.978H98.34s-3.778-.021-4.73,1.307l.007-4.049h18.5l.019,4.017c-.952-1.33-4.726-1.308-4.726-1.308h-2.568a14.228,14.228,0,0,0-.156,2.021V14.08c0,4.143,1.3,4.625,1.3,4.625Zm-23.109,0s1.3-.481,1.3-4.623V8.106s.019-3.777-1.309-4.729l6.237.009c-1.328.951-1.307,4.728-1.307,4.728v5.964c0,4.141,1.3,4.624,1.3,4.624Zm47.556-4.619V8.11s.021-3.776-1.307-4.727l17.75,0V7.389c-.951-1.328-4.731-1.307-4.731-1.307l-7.935.03a14.44,14.44,0,0,0-.155,2.006V9.361H130.7c4.144,0,4.623-1.3,4.623-1.3l0,3.729h-.01l0,1.521s-.483-1.3-4.624-1.3h-2.856v2.072a15.251,15.251,0,0,0,.087,1.707l8.174.03s3.78.02,4.731-1.308l-.014,4.179-17.9.009S124.213,18.219,124.213,14.075ZM58.153,18.69s1.3-.481,1.3-4.621V12.1H48.34v1.977c0,4.142,1.3,4.622,1.3,4.622l-6.223-.008s1.3-.481,1.3-4.621V8.1s.02-3.778-1.308-4.728l6.238.007c-1.328.951-1.307,4.729-1.307,4.729V9.274H59.455V8.105s.02-3.778-1.309-4.729l6.239.007c-1.328.951-1.308,4.73-1.308,4.73v5.963c0,4.142,1.3,4.622,1.3,4.622Zm-50.547-.06s1.353-.743.622-2.7-5.051-13.2-5.051-13.2A3.893,3.893,0,0,0,0,0L8.235,0a2.245,2.245,0,0,0-.609,2.7l3.712,9.814s3.042-7.812,3.878-9.805S14.711,0,14.711,0l6.342.012c-1.334.7-.622,2.719-.622,2.719l3.939,9.79,3.532-9.8S28.716.589,27.4,0l7.49.019A4.422,4.422,0,0,0,31.66,2.684L26.644,15.929s-.908,1.819.566,2.7l-6.3,0a2.177,2.177,0,0,0,.62-2.7L17.511,5.771,13.338,15.927s-.838,1.844.491,2.712Zm183.132-.011a2.378,2.378,0,0,0,.5-3.305H181.1c-1.273,2.2.437,3.323.437,3.323h-7.894a4.827,4.827,0,0,0,3.255-2.41s5.1-8.672,6.021-10.224a2.089,2.089,0,0,0-.625-2.7l8.04.009c-1.6,1.4-.617,2.715-.617,2.715l6.137,10.144a5.027,5.027,0,0,0,3.208,2.468Zm-8.046-6.1h7.025l-3.585-6.367Z" data-name="Union 7" fill="#f8f8f8" id="Union_7" stroke="rgba(0,0,0,0)" stroke-miterlimit="10" stroke-width="1" transform="translate(154.747 66.341)">
#              </path>
#             </g>
#            </svg>
#           </a>
#          </div>
#          <nav aria-label="Primary Menu " class="header-nav primary-menu desktop-nav" data-copychildafter-addclass="mobile-menu" data-copychildafter-sel=".top-nav.main-menu" data-copychildafter-target=".mobile-menu-search" data-copychildto-sel=".top-nav.main-menu" data-copychildto-target=".desk-sticky-nav-container" itemscope="" itemtype="https://schema.org/SiteNavigationElement" role="navigation">
#           <h2 class="screen-reader-text">
#            Primary Menu
#           </h2>
#           <ul class="nav top-nav main-menu" id="menu-main-menu" role="menubar">
#            <li class="no-desktop menu-item menu-item-type-post_type menu-item-object-page menu-item-home menu-item-304" id="menu-item-304">
#             <a href="https://whiteface.com/" role="menuitem">
#              Home Page
#             </a>
#            </li>
#            <li aria-expanded="false" aria-haspopup="true" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children menu-item-295" id="menu-item-295" tabindex="0">
#             <a href="https://whiteface.com/plan/" role="menuitem">
#              Plan Your Visit
#             </a>
#             <ul class="sub-menu">
#              <li aria-expanded="false" aria-haspopup="true" class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-302" id="menu-item-302" tabindex="0">
#               <a href="#" role="menuitem">
#                Lodging &amp; Community
#               </a>
#               <ul class="sub-menu">
#                <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-296" id="menu-item-296">
#                 <a href="https://whiteface.com/plan/lodging/" role="menuitem">
#                  Lodging
#                 </a>
#                </li>
#                <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-297" id="menu-item-297">
#                 <a href="https://whiteface.com/plan/around-town/" role="menuitem">
#                  Around Town
#                 </a>
#                </li>
#               </ul>
#              </li>
#              <li aria-expanded="false" aria-haspopup="true" class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-303" id="menu-item-303" tabindex="0">
#               <a href="#" role="menuitem">
#                Getting Here
#               </a>
#               <ul class="sub-menu">
#                <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-823" id="menu-item-823">
#                 <a href="https://whiteface.com/lessons-programs/first-timer/" role="menuitem">
#                  For First-Timers
#                 </a>
#                </li>
#                <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-300" id="menu-item-300">
#                 <a href="https://whiteface.com/plan/directions/" role="menuitem">
#                  Directions
#                 </a>
#                </li>
#                <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-301" id="menu-item-301">
#                 <a href="https://whiteface.com/plan/shuttle/" role="menuitem">
#                  Shuttle
#                 </a>
#                </li>
#               </ul>
#              </li>
#              <li aria-expanded="false" aria-haspopup="true" class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-334" id="menu-item-334" tabindex="0">
#               <a href="#" role="menuitem">
#                Groups
#               </a>
#               <ul class="sub-menu">
#                <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2316" id="menu-item-2316">
#                 <a href="https://whiteface.com/groups/" role="menuitem">
#                  Groups
#                 </a>
#                </li>
#                <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-8472" id="menu-item-8472">
#                 <a href="https://lakeplacidolympicsites.com/groups-conferences-weddings-special-events/" role="menuitem" target="_blank">
#                  Weddings
#                 </a>
#                </li>
#                <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-8473" id="menu-item-8473">
#                 <a href="https://lakeplacidolympicsites.com/groups-conferences-weddings-special-events/" role="menuitem" target="_blank">
#                  Conferences
#                 </a>
#                </li>
#                <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-331" id="menu-item-331">
#                 <a href="https://lakeplacidolympicsites.com/events/upcoming-events/#new_tab" role="menuitem" target="_blank">
#                  Olympic Sites Venues
#                 </a>
#                </li>
#               </ul>
#              </li>
#             </ul>
#            </li>
#            <li aria-expanded="false" aria-haspopup="true" class="menu-item menu-item-type-post_type menu-item-object-page current-page-ancestor current-menu-ancestor current-page-parent current_page_ancestor menu-item-has-children menu-item-305" id="menu-item-305" tabindex="0">
#             <a href="https://whiteface.com/mountain/" role="menuitem">
#              The Mountain
#             </a>
#             <ul class="sub-menu">
#              <li aria-expanded="false" aria-haspopup="true" class="menu-item menu-item-type-custom menu-item-object-custom current-menu-ancestor current-menu-parent menu-item-has-children menu-item-323" id="menu-item-323" tabindex="0">
#               <a href="#" role="menuitem">
#                Conditions &amp; Weather
#               </a>
#               <ul class="sub-menu">
#                <li class="menu-item menu-item-type-post_type menu-item-object-page current-menu-item page_item page-item-217 current_page_item menu-item-306" id="menu-item-306">
#                 <a href="https://whiteface.com/mountain/conditions/" role="menuitem">
#                  Conditions
#                 </a>
#                </li>
#                <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-308" id="menu-item-308">
#                 <a href="https://whiteface.com/mountain/webcams/" role="menuitem">
#                  Webcams
#                 </a>
#                </li>
#                <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-309" id="menu-item-309">
#                 <a href="https://whiteface.com/mountain/trail-map/" role="menuitem">
#                  Trail Map
#                 </a>
#                </li>
#                <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-3277" id="menu-item-3277">
#                 <a href="https://whiteface.com/plan/directions/" role="menuitem">
#                  Directions
#                 </a>
#                </li>
#               </ul>
#              </li>
#              <li aria-expanded="false" aria-haspopup="true" class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-324" id="menu-item-324" tabindex="0">
#               <a href="#" role="menuitem">
#                Mountain Info
#               </a>
#               <ul class="sub-menu">
#                <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-310" id="menu-item-310">
#                 <a href="https://whiteface.com/mountain/hours-of-operation/" role="menuitem">
#                  Hours of Operation
#                 </a>
#                </li>
#                <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-312" id="menu-item-312">
#                 <a href="https://whiteface.com/mountain/improvements/" role="menuitem">
#                  Improvements
#                 </a>
#                </li>
#                <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-314" id="menu-item-314">
#                 <a href="https://whiteface.com/mountain/sustainability/" role="menuitem">
#                  Sustainability
#                 </a>
#                </li>
#                <li class="menu-item menu-item-type-post_type menu-item-object-to-do menu-item-3274" id="menu-item-3274">
#                 <a href="https://whiteface.com/todo/the-slides/" role="menuitem">
#                  The Slides
#                 </a>
#                </li>
#                <li class="menu-item menu-item-type-post_type menu-item-object-to-do menu-item-3273" id="menu-item-3273">
#                 <a href="https://whiteface.com/todo/terrain-parks/" role="menuitem">
#                  Terrain Parks
#                 </a>
#                </li>
#                <li class="menu-item menu-item-type-post_type menu-item-object-to-do menu-item-5555" id="menu-item-5555">
#                 <a href="https://whiteface.com/todo/uphill-program/" role="menuitem">
#                  Uphill Program
#                 </a>
#                </li>
#                <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-315" id="menu-item-315">
#                 <a href="https://whiteface.com/mountain/mountain-safety/" role="menuitem">
#                  Safety &amp; Policies
#                 </a>
#                </li>
#                <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-10458" id="menu-item-10458">
#                 <a href="https://whiteface.com/health-safety-information/" role="menuitem">
#                  Health &amp; Safety Info
#                 </a>
#                </li>
#               </ul>
#              </li>
#              <li aria-expanded="false" aria-haspopup="true" class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-325" id="menu-item-325" tabindex="0">
#               <a href="#" role="menuitem">
#                Mountain Services
#               </a>
#               <ul class="sub-menu">
#                <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-316" id="menu-item-316">
#                 <a href="https://whiteface.com/mountain/dining/" role="menuitem">
#                  Dining
#                 </a>
#                </li>
#                <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-317" id="menu-item-317">
#                 <a href="https://whiteface.com/mountain/rentals/" role="menuitem">
#                  Rentals
#                 </a>
#                </li>
#                <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-318" id="menu-item-318">
#                 <a href="https://whiteface.com/mountain/apparel/" role="menuitem">
#                  Apparel
#                 </a>
#                </li>
#                <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-319" id="menu-item-319">
#                 <a href="https://whiteface.com/mountain/parking/" role="menuitem">
#                  Parking
#                 </a>
#                </li>
#                <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-5009" id="menu-item-5009">
#                 <a href="https://whiteface.com/mountain/lockers/" role="menuitem">
#                  Lockers
#                 </a>
#                </li>
#                <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-321" id="menu-item-321">
#                 <a href="https://whiteface.com/mountain/tuning-repair/" role="menuitem">
#                  Tuning &amp; Repair
#                 </a>
#                </li>
#                <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-322" id="menu-item-322">
#                 <a href="https://whiteface.com/mountain/lost-found/" role="menuitem">
#                  Lost &amp; Found
#                 </a>
#                </li>
#               </ul>
#              </li>
#             </ul>
#            </li>
#            <li aria-expanded="false" aria-haspopup="true" class="sub-center menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children menu-item-335" id="menu-item-335" tabindex="0">
#             <a href="https://whiteface.com/tickets-passes/" role="menuitem">
#              Tickets &amp; Passes
#             </a>
#             <ul class="sub-menu">
#              <li aria-expanded="false" aria-haspopup="true" class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-343" id="menu-item-343" tabindex="0">
#               <a href="#" role="menuitem">
#                Tickets
#               </a>
#               <ul class="sub-menu">
#                <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-336" id="menu-item-336">
#                 <a href="https://whiteface.com/tickets-passes/lift-tickets/" role="menuitem">
#                  Lift Tickets
#                 </a>
#                </li>
#                <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-6259" id="menu-item-6259">
#                 <a href="https://whiteface.com/tickets-passes/frequent-skier-cards/" role="menuitem">
#                  Frequent Skier Cards
#                 </a>
#                </li>
#                <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-337" id="menu-item-337">
#                 <a href="https://whiteface.com/tickets-passes/summer-attractions/" role="menuitem">
#                  Summer Attractions
#                 </a>
#                </li>
#               </ul>
#              </li>
#              <li aria-expanded="false" aria-haspopup="true" class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-344" id="menu-item-344" tabindex="0">
#               <a href="#" role="menuitem">
#                Passes
#               </a>
#               <ul class="sub-menu">
#                <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-8599" id="menu-item-8599">
#                 <a href="https://whiteface.com/tickets-passes/season-passes/" role="menuitem">
#                  Season Passes
#                 </a>
#                </li>
#                <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-339" id="menu-item-339">
#                 <a href="https://whiteface.com/tickets-passes/pass-perks/" role="menuitem">
#                  Pass Perks
#                 </a>
#                </li>
#               </ul>
#              </li>
#              <li aria-expanded="false" aria-haspopup="true" class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-347" id="menu-item-347" tabindex="0">
#               <a href="#" role="menuitem">
#                Other Products
#               </a>
#               <ul class="sub-menu">
#                <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-1733" id="menu-item-1733">
#                 <a href="https://whiteface.com/mountain/rentals/" role="menuitem">
#                  Rentals
#                 </a>
#                </li>
#                <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-3270" id="menu-item-3270">
#                 <a href="https://whiteface.com/mountain/tuning-repair/" role="menuitem">
#                  Tuning &amp; Repair
#                 </a>
#                </li>
#                <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-4855" id="menu-item-4855">
# ...
#             Employment
#            </a>
#           </li>
#          </ul>
#         </div>
#        </nav>
#       </div>
#       <div class="footer-07 footer-m06 footer-menu footer-helpful-info footer-managed-by">
#        <h2>
#         Managed by:
#        </h2>
#        <a href="https://www.orda.org/" rel="noopener" target="_blank">
#         <svg height="60" id="orda-cta" viewbox="0 0 321 60" width="321" xmlns="http://www.w3.org/2000/svg">
#          <rect data-name="Rectangle 890" fill="#2565A1" height="60" id="Rectangle_890" transform="translate(61)" width="260">
#          </rect>
#          <text data-name="Olympic Regional
# Development Authority" fill="#fff" font-family="Montserrat-Bold, Montserrat" font-size="14" font-weight="700" id="Olympic_Regional_Development_Authority" letter-spacing="0.05em" transform="translate(78 27)">
#           <tspan x="0" y="0">
#            OLYMPIC REGIONAL
#           </tspan>
#           <tspan x="0" y="16">
#            DEVELOPMENT AUTHORITY
#           </tspan>
#          </text>
#          <rect data-name="Rectangle 891" fill="#2565A1" height="60" id="Rectangle_891" width="60">
#          </rect>
#          <g data-name="Group 1050" id="Group_1050" transform="translate(-216.122 -51.246)">
#           <g data-name="Group 1050" id="Group_1050-2" transform="translate(243.848 64.423)">
#            <path d="M316.923,68.5a2.77,2.77,0,0,0,.846-4.076,1.9,1.9,0,0,1-.554,2.061C316.472,67.171,316.923,68.5,316.923,68.5Z" data-name="Path 3661" fill="#fff" id="Path_3661" stroke="#fff" stroke-miterlimit="10" stroke-width="1" transform="translate(-315.584 -64.423)">
#            </path>
#            <path d="M313.3,80.934a5.054,5.054,0,0,0-.857-1.649c-.694-.946-2.7-3.714-.177-5.144,2-1.131,2.21-2.651,1.893-3.471a3.755,3.755,0,0,1,.332,3.314c-.463,1-.926,1.407-.758,1.783a.422.422,0,0,0,.763.036.865.865,0,0,0-.046-.692s1.642,1.191,1.2,2.769S313.547,80.058,313.3,80.934Z" data-name="Path 3662" fill="#fff" id="Path_3662" stroke="#fff" stroke-miterlimit="10" stroke-width="1" transform="translate(-311.024 -69.365)">
#            </path>
#           </g>
#           <path d="M226.122,143.611l19.6-19.46-1.435,4.95-8.031,8.025,9.871-3.906,9.869,3.912-8.03-8.029-1.441-4.954,19.6,19.469-20-7.621Z" data-name="Path 3663" fill="#fff" id="Path_3663" stroke="#fff" stroke-miterlimit="10" stroke-width="1" transform="translate(0 -47.256)">
#           </path>
#          </g>
#         </svg>
#        </a>
#       </div>
#       <div class="footer-08 footer-m02 footer-social">
#        <div class="social-icons">
#         <div class="social-networks">
#          <a href="https://www.facebook.com/WhitefaceLakePlacid" rel="noopener" target="_blank">
#           <icon class="mdi mdi-facebook-box">
#           </icon>
#           <span>
#            Connect with us on Facebook
#           </span>
#          </a>
#          <a href="https://twitter.com/SkiWhiteface" rel="noopener" target="_blank">
#           <icon class="mdi mdi-twitter-box">
#           </icon>
#           <span>
#            Connect with us on Twitter
#           </span>
#          </a>
#          <a href="https://instagram.com/whiteface_mt" rel="noopener" target="_blank">
#           <icon class="mdi mdi-instagram">
#           </icon>
#           <span>
#            Connect with us on Instagram
#           </span>
#          </a>
#          <a href="https://www.youtube.com/WhitefaceLakePlacid" rel="noopener" target="_blank">
#           <icon class="mdi mdi-youtube">
#           </icon>
#           <span>
#            Connect with us on YouTube
#           </span>
#          </a>
#         </div>
#         <div class="nys-logo">
#          <a href="https://www.ny.gov/" rel="noopener" target="_blank">
#           <img alt="New York State" src="https://whiteface.com/wp-content/themes/plate-orda/library/images/logo/NYS-Logo-State-of-Opportunity.svg"/>
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="footer-09 footer-m07 footer-nys">
#        <div class="nys-logo">
#         <a href="https://www.ny.gov/" rel="noopener" target="_blank">
#          <img alt="New York State" src="https://whiteface.com/wp-content/themes/plate-orda/library/images/logo/NYS-Logo-State-of-Opportunity.svg"/>
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#     <!-- // end #inner-footer -->
#     <div class="footer-sponors">
#      <div class="sponsor-logos wrap">
#       <div class="glide">
#        <div class="glide__track" data-glide-el="track">
#         <ul class="glide__slides">
#          <li class="glide__slide slide-0" title="Chevrolet">
#           <a href="https://www.chevrolet.com/" target="_blank" title="Visit Chevrolet">
#            <img alt="Chevrolet" src="https://whiteface.com/wp-content/uploads/sites/3/2020/06/logo-chevrolet-min.png"/>
#           </a>
#          </li>
#          <li class="glide__slide slide-1" title="Essity">
#           <a href="https://www.essity.com/" target="_blank" title="Visit Essity">
#            <img alt="Essity" src="https://whiteface.com/wp-content/uploads/sites/3/2020/06/logo-essity-min.png"/>
#           </a>
#          </li>
#          <li class="glide__slide slide-2" title="Ellis">
#           <a href="https://www.elliscoffee.com/" target="_blank" title="Ellis Coffee">
#            <img alt="Ellis" src="https://whiteface.com/wp-content/uploads/sites/3/2021/04/ellis1-2.png"/>
#           </a>
#          </li>
#          <li class="glide__slide slide-3" title="Coca-Cola">
#           <a href="https://us.coca-cola.com/" target="_blank" title="Visit Coca-Cola">
#            <img alt="Coca-Cola" src="https://whiteface.com/wp-content/uploads/sites/3/2020/06/logo-coca-cola-min.png"/>
#           </a>
#          </li>
#          <li class="glide__slide slide-4" title="Powerade">
#           <a href="https://www.powerade.com/" target="_blank" title="Powerade Official Website">
#            <img alt="Powerade" src="https://whiteface.com/wp-content/uploads/sites/3/2021/04/poweraid-1.png"/>
#           </a>
#          </li>
#          <li class="glide__slide slide-5" title="Dasani">
#           <a href="https://www.dasani.com/" target="_blank" title="Dasani Official Website">
#            <img alt="Dasani" src="https://whiteface.com/wp-content/uploads/sites/3/2021/04/dasani-1.png"/>
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="source-org">
#      <div class="copyright wrap">
#       <span>
#        © 2021
#       </span>
#       <span class="caps">
#        Whiteface Mountain
#       </span>
#       <br/>
#       <a href="https://whiteface.com/accessibility/">
#        Accessibility
#       </a>
#       |
#       <a href="https://whiteface.com/safety/">
#        Safety
#       </a>
#       |
#       <a href="https://whiteface.com/privacy-policy/">
#        Privacy Policy
#       </a>
#       |
#       <a href="https://whiteface.com/site-map/">
#        Site Map
#       </a>
#      </div>
#     </div>
#    </footer>
#   </div>
#   <!-- // end #container -->
#   <!--googleoff: all-->
#   <div data-nosnippet="true" id="cookie-law-info-bar">
#    <span>
#     Cookies are used for measurement, ads, and optimization. By continuing to use our site you agree to our
#     <a href="https://whiteface.com/privacy-policy/">
#      privacy policy
#     </a>
#     .
#     <a class="medium cli-plugin-button cli-plugin-main-button cookie_action_close_header cli_action_button" data-cli_action="accept" id="cookie_action_close_header" role="button" style="display:inline-block;  margin:5px; " tabindex="0">
#      ACCEPT
#     </a>
#    </span>
#   </div>
#   <div data-nosnippet="true" id="cookie-law-info-again" style="display:none;">
#    <span id="cookie_hdr_showagain">
#     Privacy &amp; Cookies Policy
#    </span>
#   </div>
#   <div aria-hidden="true" aria-labelledby="cliSettingsPopup" class="cli-modal" data-nosnippet="true" id="cliSettingsPopup" role="dialog" tabindex="-1">
#    <div class="cli-modal-dialog" role="document">
#     <div class="cli-modal-content cli-bar-popup">
#      <button class="cli-modal-close" id="cliModalClose" type="button">
#       <svg class="" viewbox="0 0 24 24">
#        <path d="M19 6.41l-1.41-1.41-5.59 5.59-5.59-5.59-1.41 1.41 5.59 5.59-5.59 5.59 1.41 1.41 5.59-5.59 5.59 5.59 1.41-1.41-5.59-5.59z">
#        </path>
#        <path d="M0 0h24v24h-24z" fill="none">
#        </path>
#       </svg>
#       <span class="wt-cli-sr-only">
#        Close
#       </span>
#      </button>
#      <div class="cli-modal-body">
#       <div class="cli-container-fluid cli-tab-container">
#        <div class="cli-row">
#         <div class="cli-col-12 cli-align-items-stretch cli-px-0">
#          <div class="cli-privacy-overview">
#           <h4>
#            Privacy Overview
#           </h4>
#           <div class="cli-privacy-content">
#            <div class="cli-privacy-content-text">
#             This website uses cookies to improve your experience while you navigate through the website. Out of these cookies, the cookies that are categorized as necessary are stored on your browser as they are essential for the working of basic functionalities of the website. We also use third-party cookies that help us analyze and understand how you use this website. These cookies will be stored in your browser only with your consent. You also have the option to opt-out of these cookies. But opting out of some of these cookies may have an effect on your browsing experience.
#            </div>
#           </div>
#           <a aria-label="Show more" class="cli-privacy-readmore" data-readless-text="Show less" data-readmore-text="Show more" role="button" tabindex="0">
#           </a>
#          </div>
#         </div>
#         <div class="cli-col-12 cli-align-items-stretch cli-px-0 cli-tab-section-container">
#          <div class="cli-tab-section">
#           <div class="cli-tab-header">
#            <a class="cli-nav-link cli-settings-mobile" data-target="necessary" data-toggle="cli-toggle-tab" role="button" tabindex="0">
#             Necessary
#            </a>
#            <div class="wt-cli-necessary-checkbox">
#             <input checked="checked" class="cli-user-preference-checkbox" data-id="checkbox-necessary" id="wt-cli-checkbox-necessary" type="checkbox"/>
#             <label class="form-check-label" for="wt-cli-checkbox-necessary">
#              Necessary
#             </label>
#            </div>
#            <span class="cli-necessary-caption">
#             Always Enabled
#            </span>
#           </div>
#           <div class="cli-tab-content">
#            <div class="cli-tab-pane cli-fade" data-id="necessary">
#             <div class="wt-cli-cookie-description">
#              Necessary cookies are absolutely essential for the website to function properly. This category only includes cookies that ensures basic functionalities and security features of the website. These cookies do not store any personal information.
#             </div>
#            </div>
#           </div>
#          </div>
#          <div class="cli-tab-section">
#           <div class="cli-tab-header">
#            <a class="cli-nav-link cli-settings-mobile" data-target="non-necessary" data-toggle="cli-toggle-tab" role="button" tabindex="0">
#             Non-necessary
#            </a>
#            <div class="cli-switch">
#             <input checked="checked" class="cli-user-preference-checkbox" data-id="checkbox-non-necessary" id="wt-cli-checkbox-non-necessary" type="checkbox"/>
#             <label class="cli-slider" data-cli-disable="Disabled" data-cli-enable="Enabled" for="wt-cli-checkbox-non-necessary">
#              <span class="wt-cli-sr-only">
#               Non-necessary
#              </span>
#             </label>
#            </div>
#           </div>
#           <div class="cli-tab-content">
#            <div class="cli-tab-pane cli-fade" data-id="non-necessary">
#             <div class="wt-cli-cookie-description">
#              Any cookies that may not be particularly necessary for the website to function and is used specifically to collect user personal data via analytics, ads, other embedded contents are termed as non-necessary cookies. It is mandatory to procure user consent prior to running these cookies on your website.
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="cli-modal-footer">
#       <div class="wt-cli-element cli-container-fluid cli-tab-container">
#        <div class="cli-row">
#         <div class="cli-col-12 cli-align-items-stretch cli-px-0">
#          <div class="cli-tab-footer wt-cli-privacy-overview-actions">
#           <a class="wt-cli-privacy-btn cli_setting_save_button wt-cli-privacy-accept-btn cli-btn" data-cli-action="accept" id="wt-cli-privacy-save-btn" role="button" tabindex="0">
#            SAVE &amp; ACCEPT
#           </a>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="cli-modal-backdrop cli-fade cli-settings-overlay">
#   </div>
#   <div class="cli-modal-backdrop cli-fade cli-popupbar-overlay">
#   </div>
#   <!--googleon: all-->
#   <!-- Instagram Feed JS -->
#   <script type="text/javascript">
#    var sbiajaxurl = "https://whiteface.com/wp-admin/admin-ajax.php";
#   </script>
#   <script id="orda-conditions-js-js" src="https://whiteface.com/wp-content/plugins/orda-conditions/js/min/orda-conditions.min.js?ver=20210806-113449" type="text/javascript">
#   </script>
#   <script id="orda-lodging-js-js" src="https://whiteface.com/wp-content/plugins/orda-lodging/js/min/orda-lodging.min.js?ver=20200727-142140" type="text/javascript">
#   </script>
#   <script id="glideJS-core-js" src="https://cdn.jsdelivr.net/npm/@glidejs/glide@3.4.1/dist/glide.min.js?ver=20210527-115409" type="text/javascript">
#   </script>
#   <script id="darksky-icons-js" src="https://whiteface.com/wp-content/themes/plate-orda/library/js/libs/darksky-icons.js?ver=1638275244" type="text/javascript">
#   </script>
#   <script id="clamp-js-js" src="https://whiteface.com/wp-content/themes/plate-orda/library/js/libs/clamp.new.js?ver=1638275244" type="text/javascript">
#   </script>
#   <script id="fancybox-js-js" src="https://cdnjs.cloudflare.com/ajax/libs/fancybox/3.5.7/jquery.fancybox.min.js?ver=20210527-115409" type="text/javascript">
#   </script>
#   <script id="jquery.scrollto-js" src="https://cdnjs.cloudflare.com/ajax/libs/jquery-scrollTo/2.1.2/jquery.scrollTo.min.js?ver=20210527-115409" type="text/javascript">
#   </script>
#   <script id="plate-js-js" src="https://whiteface.com/wp-content/themes/plate-orda/library/js/min/scripts-min.js?ver=1638275244" type="text/javascript">
#   </script>
#   <script id="child-scripts-js" src="https://whiteface.com/wp-content/themes/child-whiteface/library/js/min/child-scripts.min.js?ver=1638275244" type="text/javascript">
#   </script>
#   <script id="page-links-to-js" src="https://whiteface.com/wp-content/plugins/page-links-to/dist/new-tab.js?ver=3.3.5" type="text/javascript">
#   </script>
#   <script id="gforms_recaptcha_recaptcha-js-extra" type="text/javascript">
#    /* <![CDATA[ */
# var gforms_recaptcha_recaptcha_strings = {"site_key":"6Lfpj8ocAAAAADzDr1s1oZ7TdQmbiOK7KIzYmwfF","ajaxurl":"https:\/\/whiteface.com\/wp-admin\/admin-ajax.php","nonce":"3443d531af"};
# /* ]]> */
#   </script>
#   <script id="gforms_recaptcha_recaptcha-js" src="https://www.google.com/recaptcha/api.js?render=6Lfpj8ocAAAAADzDr1s1oZ7TdQmbiOK7KIzYmwfF&amp;ver=1.1" type="text/javascript">
#   </script>
#   <script id="scroll-watcher-js" src="https://cdn.jsdelivr.net/npm/scroll-watcher@latest/dist/scroll-watcher.min.js?ver=20210527-115409" type="text/javascript">
#   </script>
#   <script id="plate-a11y-js" src="https://whiteface.com/wp-content/themes/plate-orda/library/js/a11y.js?ver=1638275244" type="text/javascript">
#   </script>
#   <script id="wp-embed-js" src="https://whiteface.com/wp-includes/js/wp-embed.min.js?ver=5.8.2" type="text/javascript">
#   </script>
#   <script src="https://orda-whitefacelakeplacid.secure-cdn.na2.accessoticketing.com/embed/accesso.js" type="text/javascript">
#   </script>
#  </body>
# </html>
# <!-- This is the end. My only friend. -->
# <!-- Dynamic page generated in 0.546 seconds. -->
# <!-- Cached page generated by WP-Super-Cache on 2021-11-30 10:11:39 -->
# <!-- Compression = gzip -->

# %%
#inspect the page to find the names of the stuff you want
#I want to know the number of lifts open, the number of trails open, the new snow

lifts=soup2.find(class_='report-box lifts')
trails=soup2.find(class_='report-box trails')

# %%
print(lifts.get_text())
# Out:
# Lifts
#
# 2
# of 11

# %%
print(trails.get_text())
# Out:
# Trails
#
# 7
# of 90

# %% [markdown]
# What if I just want the numbers 2 and 7 and not all the rest? Let's have a look at what *lifts* and *trails* actually are?

# %%
type(trails)
# Out:
# bs4.element.Tag

# %% [markdown]
# So *trails* is what's called a Tag element. Let's look at it in the raw:

# %%
trails
# Out:
# <div class="report-box trails">
# <div class="title">Trails</div>
# <div class="main-detail">
# <span class="primary">7</span>
# <span class="secondary">of 90</span>
# </div>
# <div class="sub-detail"></div>
# </div>

# %% [markdown]
# Notice there are many tags within the "report-box trails" tag. How do we get at these?  One way is to use the contents attribute of a bs4 Tag element. This gives us a list of the contents of the tag.

# %%
trails.contents
# Out:
# ['\n',
#  <div class="title">Trails</div>,
#  '\n',
#  <div class="main-detail">
#  <span class="primary">7</span>
#  <span class="secondary">of 90</span>
#  </div>,
#  '\n',
#  <div class="sub-detail"></div>,
#  '\n']

# %% [markdown]
# Notice that the fourth element of *trails.contents* is another tag and that tag also has children tags. To get at those we can use contents again and finally we can recover the text.

# %%
trails.contents[3].contents[1].get_text()
# Out:
# '7'

# %% [markdown]
# Now what if we want more detail? That is, suppose I want a list of all of the open lifts. Once again we need to return to the source code and find the class names we are interested in.

# %%
status=soup2.find_all(class_='lift-icon data-icon')

# %%
#notice the structure is a little more complex this time
type(status[0].contents[0])
# Out:
# bs4.element.Tag

# %%
for element in status:
    print(element.contents[0]['title'])
# Out:
# Cloudsplitter Gondola is open
# Lookout Mountain Triple Chair is closed
# Little Whiteface Lift is closed
# Freeway Lift is closed
# Mountain Run Lift is closed
# Face Lift is open
# Bear Lift is closed
# Summit Quad is closed
# Falcon Flyer Quad is closed
# Cub Carpet is closed
# Coyote Carpet is closed

# %% [markdown]
# **Scraping is involved**: Scraping data from webpages is a relatively ad-hoc procedure. You need to experiment with the page you're interested in and always keep in mind that pages change so what you write today will most likely not work in the near future.
